# %%
from bs4 import BeautifulSoup
import requests
import csv
from itertools import zip_longest
import pandas as pd
import time
import numpy as np

# %%
page_num = 1
Central_Riyadh = {
                "shoptitle" :[],
                "prices"  : [],
                "areaa"  : [],
                "links" : []
                
                
            }
while True:

    if(page_num == 7):
        print("pages ended, terminate")
        break
        
    url= requests.get(f'https://sa.aqar.fm/%D9%85%D8%AD%D9%84%D8%A7%D8%AA-%D9%84%D9%84%D8%A5%D9%8A%D8%AC%D8%A7%D8%B1/%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/%D9%88%D8%B3%D8%B7-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6/{page_num}','utf8')
    shops= url.content
    soup= BeautifulSoup (shops,"lxml")
    
    shopstitles = soup.find_all('h4',{'class':'listTitle'})
    price= soup.find_all('span',{'class':'price'})
    area= soup.find_all('span',{'class':'size'})
    
    
    for i in range(len(shopstitles)):
        Central_Riyadh["shoptitle"].append(shopstitles[i].text)
        #site_list["links"].append(shopstitles[i].find('a',{'class':'listTitle'}).attrs['href'])
        Central_Riyadh["prices"].append(price[i].text)
        Central_Riyadh["areaa"].append(area[i].text)
        Central_Riyadh["links"].append(shopstitles[i].find('a',{'class':'listTitle'}).attrs['href'])
   


        
        
    
    page_num+= 1
    print("page switched to page "+ str(page_num))
# Out:
# page switched to page 2
# page switched to page 3
# page switched to page 4
# page switched to page 5
# page switched to page 6
# page switched to page 7
# pages ended, terminate

# %%
import pandas as pd
dfCenter = pd.DataFrame(Central_Riyadh)
dfCenter
# Out:
#                                              shoptitle        prices    areaa  \
# 0    محل للإيجار في شارع أم رومان ، حي الضباط ، الر...  375,000 ريال   290 م²
# 1    محل للإيجار في طريق الملك فهد الفرعي ، حي الوش...   29,100 ريال    77 م²
# 2    محل للإيجار في شارع ابي زكريا بن العوام ، حي ع...   33,000 ريال   200 م²
# 3    محل للإيجار في حي ، طريق الأمير محمد بن عبدالر...   25,000 ريال    40 م²
# 4       محل للإيجار في شارع البطحاء ، حي جبرة ، الرياض   15,000 ريال  1000 م²
# ..                                                 ...           ...      ...
# 115  محل للإيجار في طريق صلاح الدين الأيوبي ، حي ال...  390,000 ريال   400 م²
# 116  محل للإيجار في شارع نجران ، حي الفيصلية ، الري...    1,200 ريال   930 م²
# 117  محل للإيجار في شارع أبي ذر الغفاري ، حي الربوة...   13,000 ريال    24 م²
# 118  محل للإيجار في حي ، شارع عبداللطيف المعشوق ، ح...   13,500 ريال    30 م²
# 119         محل للإيجار في الرياض ، حي الربوة ، الرياض   55,000 ريال    28 م²
#
#                                                  links
# 0    /محلات-للإيجار/الرياض/وسط-الرياض/حي-الضباط/شار...
# 1    /محلات-للإيجار/الرياض/وسط-الرياض/حي-الوشام/طري...
# 2    /محلات-للإيجار/الرياض/وسط-الرياض/حي-عتيقة/شارع...
# 3    /محلات-للإيجار/الرياض/وسط-الرياض/حي-منفوحة-الج...
# 4    /محلات-للإيجار/الرياض/وسط-الرياض/حي-جبرة/شارع-...
# ..                                                 ...
# 115  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الزهراء/طر...
# 116  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الفيصلية/ش...
# 117  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الربوة/شار...
# 118  /محلات-للإيجار/الرياض/وسط-الرياض/حي-غبيرة/حي-ش...
# 119  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الربوة/الر...
#
# [120 rows x 4 columns]

# %%
dfCentral = pd.read_csv("Central_Riyadh.csv")
dfCentral
# Out:
#      Unnamed: 0                                          shoptitle  \
# 0             0  محل للإيجار في شارع أم رومان ، حي الضباط ، الر...
# 1             1  محل للإيجار في طريق الملك فهد الفرعي ، حي الوش...
# 2             2  محل للإيجار في شارع ابي زكريا بن العوام ، حي ع...
# 3             3  محل للإيجار في حي ، طريق الأمير محمد بن عبدالر...
# 4             4     محل للإيجار في شارع البطحاء ، حي جبرة ، الرياض
# ..          ...                                                ...
# 115         115  محل للإيجار في طريق صلاح الدين الأيوبي ، حي ال...
# 116         116  محل للإيجار في شارع نجران ، حي الفيصلية ، الري...
# 117         117  محل للإيجار في شارع أبي ذر الغفاري ، حي الربوة...
# 118         118  محل للإيجار في حي ، شارع عبداللطيف المعشوق ، ح...
# 119         119         محل للإيجار في الرياض ، حي الربوة ، الرياض
#
#            prices    areaa                                              links
# 0    375,000 ريال   290 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الضباط/شار...
# 1     29,100 ريال    77 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الوشام/طري...
# 2     33,000 ريال   200 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-عتيقة/شارع...
# 3     25,000 ريال    40 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-منفوحة-الج...
# 4     15,000 ريال  1000 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-جبرة/شارع-...
# ..            ...      ...                                                ...
# 115  390,000 ريال   400 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الزهراء/طر...
# 116    1,200 ريال   930 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الفيصلية/ش...
# 117   13,000 ريال    24 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الربوة/شار...
# 118   13,500 ريال    30 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-غبيرة/حي-ش...
# 119   55,000 ريال    28 م²  /محلات-للإيجار/الرياض/وسط-الرياض/حي-الربوة/الر...
#
# [120 rows x 5 columns]

# %%
soup_list3 = []
for index, l in enumerate(dfCenter["links"]):
    newlink3 = requests.get("https://sa.aqar.fm" + l)
    #print(newlink.status_code)
    src3 = newlink3.text
    soup3 = BeautifulSoup(src3, "lxml")
    soup_list3.append(soup3)
    time.sleep(3)

# %%
page_dict3 = {
    "front": [],
    "street_width":[],
    "age":[]
}
for ss in soup_list3:
    #print(ss.find('table',class_="dc-detailsTable").find_all("td")[0].text)
    page_dict3["front"].append(ss.find('table',class_="dc-detailsTable").find_all("td")[2].text)
    try:
        page_dict3["age"].append(ss.find('table',class_="dc-detailsTable").find_all("td")[6].text)
        page_dict3["street_width"].append(ss.find('table',class_="dc-detailsTable").find_all("td")[4].text)
    
    except:
        page_dict3["age"].append(np.nan)
        page_dict3["street_width"].append(np.nan)
sub_d3 = pd.DataFrame(page_dict3)

# %%
df_merg_south= dfCenter.merge(sub_d3, left_index=True, right_index=True)
df_merg_south

# %%
df_merg_south.to_csv("final_Central.csv", encoding="utf-8"
